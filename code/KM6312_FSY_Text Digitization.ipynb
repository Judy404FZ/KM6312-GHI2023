# %%
import pandas as pd
file_name = "KM6312.csv"
pd.read_csv("C:\\users\范思源\Desktop\KM6312\KM6312.csv")
# Out:
#      year Country Name                      region developing_or_developed   \
# 0    2015      Albania  Central and Eastern Europe               developing
# 1    2016      Albania  Central and Eastern Europe               developing
# 2    2017      Albania  Central and Eastern Europe               developing
# 3    2018      Albania  Central and Eastern Europe               developing
# 4    2019      Albania  Central and Eastern Europe               developing
# ..    ...          ...                         ...                      ...
# 801  2019       Zambia          Sub-Saharan Africa               developing
# 802  2020       Zambia          Sub-Saharan Africa               developing
# 803  2021       Zambia          Sub-Saharan Africa               developing
# 804  2022       Zambia          Sub-Saharan Africa               developing
# 805  2023       Zambia          Sub-Saharan Africa               developing
#
#      happiness_score  gdp_per_capita  social_support  \
# ...

# %%
df_data = pd.read_csv("C:\\users\范思源\Desktop\KM6312\KM6312.csv")

# %%
df_used = pd.get_dummies(df_data,columns=['region','developing_or_developed '])
df_used
# Out:
#      year Country Name  happiness_score  gdp_per_capita  social_support  \
# 0    2015      Albania           4.9590        0.878670        0.804340
# 1    2016      Albania           4.6550        0.955300        0.501630
# 2    2017      Albania           4.6440        0.996193        0.803685
# 3    2018      Albania           4.5860        0.916000        0.817000
# 4    2019      Albania           4.7190        0.947000        0.848000
# ..    ...          ...              ...             ...             ...
# 801  2019       Zambia           4.1070        0.578000        1.058000
# 802  2020       Zambia           3.7594        0.536834        0.896037
# 803  2021       Zambia           4.0730        0.528000        0.552000
# 804  2022       Zambia           3.7600        0.930000        0.577000
# 805  2023       Zambia           3.9820        0.914000        0.890000
#
#      hearlthy_life_expentancy  freedom_to_make_life_choices  generosity  \
# ...

# %%
df_2=pd.DataFrame(df_used)
df_2.to_excel('KM6312_output.xlsx',index=False)
